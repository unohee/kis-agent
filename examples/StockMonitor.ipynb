# %% [raw]
# # PyKIS Agent 테스트 노트북
#
# 이 노트북은 PyKIS Agent 클래스를 통해 모든 주식 API를 테스트합니다.

# %%
import sys
import os
sys.path.append('..')

from pykis.core.agent import Agent
import json
import time

# 테스트 대상 종목
TEST_STOCK = "005930"  # 삼성전자

# Agent 초기화
agent = Agent()
print("🚀 PyKIS Agent 초기화 완료")
# Out:
# 🚀 PyKIS Agent 초기화 완료

# %% [raw]
# # PyKIS API 전체 메서드 테스트 시스템
#
# 이 노트북은 PyKIS의 모든 API 메서드를 체계적으로 테스트하는 종합 테스트 시스템입니다.
#
# ## 🎯 목표
# - PyKIS의 모든 메서드를 개별적으로 테스트
# - 실제 API 응답을 실시간으로 확인
# - 오류가 발생하는 메서드 식별
# - API 일관성 검증
#
# ## 📋 테스트 범위
# ### 1. StockAPI 클래스 (stock/api.py)
# - 주식 시세 조회
# - 일별/분봉 데이터
# - 회원사 정보
# - 투자자별 매매동향
# - 호가/체결 정보
# - 계좌 잔고 조회
#
# ### 2. ProgramTradeAPI 클래스 (program/api.py)
# - 종목별 프로그램매매추이(일별)
# - 프로그램매매 요약
# - 순매수량 조회
#
# ### 3. ProgramTradeAPI 클래스 (program/trade.py)
# - 시간별 프로그램매매 추이
# - 기간별 상세 분석
#
# ### 4. KISAgent 클래스 (core/agent.py)
# - 통합 인터페이스 테스트
#
# ## 🚀 사용 방법
# 1. 각 셀을 순차적으로 실행
# 2. 실패한 API는 오류 메시지 확인
# 3. 성공한 API는 응답 데이터 구조 분석
# 4. 문제가 있는 메서드는 별도 수정

# %% [raw]
# # 📊 테스트 결과 요약
#
# 이 섹션에서는 전체 테스트 실행 후 결과를 요약합니다.
#
# ## ✅ 성공한 메서드
# - 실제 데이터 반환
# - 올바른 응답 구조
#
# ## ❌ 실패한 메서드
# - 오류 메시지 및 원인
# - 수정이 필요한 파라미터
#
# ## ⚠️ 부분 성공한 메서드
# - 응답은 받지만 데이터가 없는 경우
# - 파라미터 조정이 필요한 경우
#
# ## 📈 통계
# - 전체 테스트 메서드 수: [자동 계산]
# - 성공률: [자동 계산]
# - 권장 사용 메서드: [목록]

# %%
# 📚 필요한 라이브러리 임포트
import os
import sys
import time
import json
import logging
import pandas as pd
from datetime import datetime, timedelta
from typing import Dict, List, Optional, Any

# PyKIS 라이브러리 임포트 (Agent 클래스만 - Facade 패턴)
from pykis import Agent

# 현재 디렉토리를 Python 경로에 추가
current_dir = os.path.dirname(os.path.abspath(__file__)) if '__file__' in globals() else os.getcwd()
if current_dir not in sys.path:
    sys.path.append(current_dir)

# 테스트 결과 저장용 딕셔너리
test_results = {
    'success': [],
    'failed': [],
    'partial': [],
    'total_tests': 0
}

def test_api_method(method_name, method_func, *args, **kwargs):
    """API 메서드 테스트 헬퍼 함수"""
    global test_results
    test_results['total_tests'] += 1
    
    print(f"\n🔍 테스트: {method_name}")
    print(f"📝 파라미터: args={args}, kwargs={kwargs}")
    
    try:
        start_time = time.time()
        result = method_func(*args, **kwargs)
        elapsed_time = time.time() - start_time
        
        if result is None:
            print(f"❌ 실패: {method_name} - 결과 없음")
            test_results['failed'].append(method_name)
            return None
        elif isinstance(result, dict):
            rt_cd = result.get('rt_cd')
            if rt_cd == '0':
                print(f"✅ 성공: {method_name} (응답시간: {elapsed_time:.2f}초)")
                print(f"📊 응답 키: {list(result.keys())}")
                if 'output' in result:
                    output = result['output']
                    if isinstance(output, list) and len(output) > 0:
                        print(f"📋 데이터 수: {len(output)}개")
                    elif isinstance(output, dict):
                        print(f"📋 데이터 키: {list(output.keys())}")
                test_results['success'].append(method_name)
                return result
            else:
                print(f"⚠️ 부분 성공: {method_name} - rt_cd: {rt_cd}, msg: {result.get('msg1', '')}")
                test_results['partial'].append(method_name)
                return result
        else:
            print(f"✅ 성공: {method_name} - 타입: {type(result)}")
            test_results['success'].append(method_name)
            return result
            
    except Exception as e:
        print(f"❌ 예외 발생: {method_name} - {str(e)}")
        test_results['failed'].append(method_name)
        return None

print("📦 라이브러리 임포트 완료 (통일된 방식)")
print("🧪 테스트 헬퍼 함수 정의 완료")
# Out:
# 📦 라이브러리 임포트 완료 (통일된 방식)
# 🧪 테스트 헬퍼 함수 정의 완료

# %%
# 🔧 PyKIS 클라이언트 및 API 인스턴스 초기화 (통일된 방식)
try:
    # Agent 클래스 초기화 (메인 통합 인터페이스)
    agent = Agent()
    print("✅ Agent 초기화 성공 (메인 클래스)")
    
    # 개별 API 접근을 위한 하위 객체들 확인
    print("📋 Agent 내부 구조:")
    print(f"   • agent.stock_api: {hasattr(agent, 'stock_api')}")
    print(f"   • agent.program_api: {hasattr(agent, 'program_api')}")
    print(f"   • agent.account_api: {hasattr(agent, 'account_api')}")
    
    # 테스트용 종목 코드
    TEST_STOCK = "005930"  # 삼성전자
    TEST_DATE = datetime.now().strftime('%Y%m%d')
    
    print(f"\n🎯 테스트 대상 종목: {TEST_STOCK} (삼성전자)")
    print(f"📅 테스트 기준일: {TEST_DATE}")
    print("🚀 Agent 기반 통합 인터페이스로 테스트를 시작합니다!")
    
    # Agent가 어떤 메서드들을 제공하는지 확인
    agent_methods = [method for method in dir(agent) if not method.startswith('_') and callable(getattr(agent, method))]
    print(f"\n📚 Agent 클래스에서 사용 가능한 메서드: {len(agent_methods)}개")
    
    # 주요 메서드들 확인
    key_methods = ['get_stock_price', 'get_daily_price', 'get_stock_member', 'get_program_trade_summary']
    available_key_methods = [method for method in key_methods if hasattr(agent, method)]
    print(f"🔑 주요 메서드 사용 가능: {available_key_methods}")
    
except Exception as e:
    print(f"❌ 초기화 실패: {str(e)}")
    print("🔧 환경변수 설정을 확인해주세요 (.env 파일)")
# Out:
# ✅ Agent 초기화 성공 (메인 클래스)
# 📋 Agent 내부 구조:
#    • agent.stock_api: True
#    • agent.program_api: True
#    • agent.account_api: True
#
# 🎯 테스트 대상 종목: 005930 (삼성전자)
# 📅 테스트 기준일: 20250619
# 🚀 Agent 기반 통합 인터페이스로 테스트를 시작합니다!
#
# 📚 Agent 클래스에서 사용 가능한 메서드: 26개
# 🔑 주요 메서드 사용 가능: ['get_stock_price', 'get_daily_price', 'get_stock_member', 'get_program_trade_summary']

# %%
# 🏢 Agent 테스트 - 주식 기본 정보
print("=" * 50)
print("📈 Agent 주식 기본 정보 테스트")
print("=" * 50)

# 1. 주식 현재가 조회
test_api_method("get_stock_price", agent.get_stock_price, TEST_STOCK)

# 2. 일별 시세 조회 
test_api_method("get_daily_price", agent.get_daily_price, TEST_STOCK)

# 3. 주식당일분봉조회 (Postman 검증됨)
test_api_method("get_minute_price", agent.get_minute_price, TEST_STOCK, "153000")

# 4. 거래원 조회
test_api_method("get_member", agent.get_member, TEST_STOCK)
# Out:
# ==================================================
# 📈 Agent 주식 기본 정보 테스트
# ==================================================
#
# 🔍 테스트: get_stock_price
# 📝 파라미터: args=('005930',), kwargs={}
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# ✅ 성공: get_stock_price (응답시간: 0.13초)
# 📊 응답 키: ['output', 'rt_cd', 'msg_cd', 'msg1']
# 📋 데이터 키: ['iscd_stat_cls_code', 'marg_rate', 'rprs_mrkt_kor_name', 'bstp_kor_isnm', 'temp_stop_yn', 'oprc_rang_cont_yn', 'clpr_rang_cont_yn', 'crdt_able_yn', 'grmn_rate_cls_code', 'elw_pblc_yn', 'stck_prpr', 'prdy_vrss', 'prdy_vrss_sign', 'prdy_ctrt', 'acml_tr_pbmn', 'acml_vol', 'prdy_vrss_vol_rate', 'stck_oprc', 'stck_hgpr', 'stck_lwpr', 'stck_mxpr', 'stck_llam', 'stck_sdpr', 'wghn_avrg_stck_prc', 'hts_frgn_ehrt', 'frgn_ntby_qty', 'pgtr_ntby_qty', 'pvt_scnd_dmrs_prc', 'pvt_frst_dmrs_prc', 'pvt_pont_val', 'pvt_frst_dmsp_prc', 'pvt_scnd_dmsp_prc', 'dmrs_val', 'dmsp_val', 'cpfn', 'rstc_wdth_prc', 'stck_fcam', 'stck_sspr', 'aspr_unit', 'hts_deal_qty_unit_val', 'lstn_stcn', 'hts_avls', 'per', 'pbr', 'stac_month', 'vol_tnrt', 'eps', 'bps', 'd250_hgpr', 'd250_hgpr_date', 'd250_hgpr_vrss_prpr_rate', 'd250_lwpr', 'd250_lwpr_date', 'd250_lwpr_vrss_prpr_rate', 'stck_dryy_hgpr', 'dryy_hgpr_vrss_prpr_rate', 'dryy_hgpr_date', 'stck_dryy_lwpr', 'dryy_lwpr_vrss_prpr_rate', 'dryy_lwpr_date', 'w52_hgpr', 'w52_hgpr_vrss_prpr_ctrt', 'w52_hgpr_date', 'w52_lwpr', 'w52_lwpr_vrss_prpr_ctrt', 'w52_lwpr_date', 'whol_loan_rmnd_rate', 'ssts_yn', 'stck_shrn_iscd', 'fcam_cnnm', 'cpfn_cnnm', 'frgn_hldn_qty', 'vi_cls_code', 'ovtm_vi_cls_code', 'last_ssts_cntg_qty', 'invt_caful_yn', 'mrkt_warn_cls_code', 'short_over_yn', 'sltr_yn', 'mang_issu_cls_code']
#
# 🔍 테스트: get_daily_price
# 📝 파라미터: args=('005930',), kwargs={}
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# 2025-06-19 00:11:55,596 - pykis.core.client - ERROR - [FHKST03010200] JSON 디코드 실패 (시도 1/5):
# ✅ 성공: get_daily_price (응답시간: 0.17초)
# 📊 응답 키: ['output', 'rt_cd', 'msg_cd', 'msg1']
# 📋 데이터 수: 30개
#
# 🔍 테스트: get_minute_price
# 📝 파라미터: args=('005930', '153000'), kwargs={}
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# ⚠️ 부분 성공: get_minute_price - rt_cd: JSON_DECODE_ERROR, msg: JSON 디코드 실패
#
# 🔍 테스트: get_member
# 📝 파라미터: args=('005930',), kwargs={}
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# ✅ 성공: get_member (응답시간: 0.09초)
# 📊 응답 키: ['output', 'rt_cd', 'msg_cd', 'msg1']
# 📋 데이터 키: ['seln_mbcr_no1', 'seln_mbcr_no2', 'seln_mbcr_no3', 'seln_mbcr_no4', 'seln_mbcr_no5', 'seln_mbcr_name1', 'seln_mbcr_name2', 'seln_mbcr_name3', 'seln_mbcr_name4', 'seln_mbcr_name5', 'total_seln_qty1', 'total_seln_qty2', 'total_seln_qty3', 'total_seln_qty4', 'total_seln_qty5', 'seln_mbcr_rlim1', 'seln_mbcr_rlim2', 'seln_mbcr_rlim3', 'seln_mbcr_rlim4', 'seln_mbcr_rlim5', 'seln_qty_icdc1', 'seln_qty_icdc2', 'seln_qty_icdc3', 'seln_qty_icdc4', 'seln_qty_icdc5', 'shnu_mbcr_no1', 'shnu_mbcr_no2', 'shnu_mbcr_no3', 'shnu_mbcr_no4', 'shnu_mbcr_no5', 'shnu_mbcr_name1', 'shnu_mbcr_name2', 'shnu_mbcr_name3', 'shnu_mbcr_name4', 'shnu_mbcr_name5', 'total_shnu_qty1', 'total_shnu_qty2', 'total_shnu_qty3', 'total_shnu_qty4', 'total_shnu_qty5', 'shnu_mbcr_rlim1', 'shnu_mbcr_rlim2', 'shnu_mbcr_rlim3', 'shnu_mbcr_rlim4', 'shnu_mbcr_rlim5', 'shnu_qty_icdc1', 'shnu_qty_icdc2', 'shnu_qty_icdc3', 'shnu_qty_icdc4', 'shnu_qty_icdc5', 'glob_total_seln_qty', 'glob_seln_rlim', 'glob_ntby_qty', 'glob_total_shnu_qty', 'glob_shnu_rlim', 'seln_mbcr_glob_yn_1', 'seln_mbcr_glob_yn_2', 'seln_mbcr_glob_yn_3', 'seln_mbcr_glob_yn_4', 'seln_mbcr_glob_yn_5', 'shnu_mbcr_glob_yn_1', 'shnu_mbcr_glob_yn_2', 'shnu_mbcr_glob_yn_3', 'shnu_mbcr_glob_yn_4', 'shnu_mbcr_glob_yn_5', 'glob_total_seln_qty_icdc', 'glob_total_shnu_qty_icdc']
# {'output': {'seln_mbcr_no1': '00005',
#   'seln_mbcr_no2': '00086',
#   'seln_mbcr_no3': '00017',
#   'seln_mbcr_no4': '00050',
#   'seln_mbcr_no5': '00003',
#   'seln_mbcr_name1': '미래에셋증권',
#   'seln_mbcr_name2': 'BNK증권',
#   'seln_mbcr_name3': 'KB증권',
#   'seln_mbcr_name4': '키움증권',
#   'seln_mbcr_name5': '한국증권',
#   'total_seln_qty1': '1977184',
#   'total_seln_qty2': '1635039',
#   'total_seln_qty3': '1477479',
#   'total_seln_qty4': '1238424',
#   'total_seln_qty5': '1199766',
#   'seln_mbcr_rlim1': '11.22',
#   'seln_mbcr_rlim2': '9.28',
#   'seln_mbcr_rlim3': '8.38',
#   'seln_mbcr_rlim4': '7.03',
#   'seln_mbcr_rlim5': '6.81',
#   'seln_qty_icdc1': '143554',
#   'seln_qty_icdc2': '12208',
#   'seln_qty_icdc3': '125750',
#   'seln_qty_icdc4': '1238424',
#   'seln_qty_icdc5': '49485',
#   'shnu_mbcr_no1': '00086',
#   'shnu_mbcr_no2': '00005',
#   'shnu_mbcr_no3': '00033',
#   'shnu_mbcr_no4': '00003',
#   'shnu_mbcr_no5': '00063',
#   'shnu_mbcr_name1': 'BNK증권',
#   'shnu_mbcr_name2': '미래에셋증권',
#   'shnu_mbcr_name3': 'JP모간',
#   'shnu_mbcr_name4': '한국증권',
#   'shnu_mbcr_name5': 'LS증권',
#   'total_shnu_qty1': '1612632',
#   'total_shnu_qty2': '1543442',
#   'total_shnu_qty3': '1362049',
#   'total_shnu_qty4': '1333866',
#   'total_shnu_qty5': '1115461',
#   'shnu_mbcr_rlim1': '9.15',
#   'shnu_mbcr_rlim2': '8.76',
#   'shnu_mbcr_rlim3': '7.73',
#   'shnu_mbcr_rlim4': '7.57',
#   'shnu_mbcr_rlim5': '6.33',
#   'shnu_qty_icdc1': '553',
#   'shnu_qty_icdc2': '26730',
#   'shnu_qty_icdc3': '86438',
#   'shnu_qty_icdc4': '70461',
#   'shnu_qty_icdc5': '223',
#   'glob_total_seln_qty': '694722',
#   'glob_seln_rlim': '3.94',
#   'glob_ntby_qty': '779388',
#   'glob_total_shnu_qty': '1474110',
#   'glob_shnu_rlim': '8.37',
#   'seln_mbcr_glob_yn_1': 'N',
#   'seln_mbcr_glob_yn_2': 'N',
#   'seln_mbcr_glob_yn_3': 'N',
#   'seln_mbcr_glob_yn_4': 'N',
#   'seln_mbcr_glob_yn_5': 'N',
#   'shnu_mbcr_glob_yn_1': 'N',
#   'shnu_mbcr_glob_yn_2': 'N',
#   'shnu_mbcr_glob_yn_3': 'Y',
#   'shnu_mbcr_glob_yn_4': 'N',
#   'shnu_mbcr_glob_yn_5': 'N',
#   'glob_total_seln_qty_icdc': '0',
#   'glob_total_shnu_qty_icdc': '86438'},
#  'rt_cd': '0',
#  'msg_cd': 'MCA00000',
#  'msg1': '정상처리 되었습니다.'}

# %%
# 📊 Agent 테스트 - 프로그램 매매 정보
print("=" * 50)
print("📊 Agent 프로그램 매매 테스트")
print("=" * 50)

# 1. 프로그램 매매 요약 조회
test_api_method("get_program_trade_summary", agent.get_program_trade_summary, TEST_STOCK)

# 2. 시간별 프로그램 매매 추이
test_api_method("get_program_trade_hourly_trend", agent.get_program_trade_hourly_trend, TEST_STOCK)

# 3. 일별 프로그램 매매 집계
test_api_method("get_program_trade_daily_summary", agent.get_program_trade_daily_summary, TEST_STOCK, TEST_DATE)

# 4. 프로그램 매매 종합 정보
test_api_method("get_pgm_trade", agent.get_pgm_trade, TEST_STOCK, TEST_DATE)
# Out:
# ==================================================
# 📊 Agent 프로그램 매매 테스트
# ==================================================
#
# 🔍 테스트: get_program_trade_summary
# 📝 파라미터: args=('005930',), kwargs={}
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# ❌ 실패: get_program_trade_summary - 결과 없음
#
# 🔍 테스트: get_program_trade_hourly_trend
# 📝 파라미터: args=('005930',), kwargs={}
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# ✅ 성공: get_program_trade_hourly_trend (응답시간: 0.05초)
# 📊 응답 키: ['output', 'rt_cd', 'msg_cd', 'msg1']
# 📋 데이터 수: 30개
#
# 🔍 테스트: get_program_trade_daily_summary
# 📝 파라미터: args=('005930', '20250619'), kwargs={}
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# ✅ 성공: get_program_trade_daily_summary (응답시간: 0.08초)
# 📊 응답 키: ['output', 'rt_cd', 'msg_cd', 'msg1']
# 📋 데이터 수: 30개
#
# 🔍 테스트: get_pgm_trade
# 📝 파라미터: args=('005930', '20250619'), kwargs={}
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# ❌ 실패: get_pgm_trade - 결과 없음

# %%
# 🏦 Agent 테스트 - 회원사 및 거래 정보
print("=" * 50)
print("🏦 Agent 회원사/거래 테스트")
print("=" * 50)

# 1. 회원사 매매 정보 조회
test_api_method("get_member_transaction", agent.get_member_transaction, TEST_STOCK)

# 2. 체결강도 순위 조회
test_api_method("get_volume_power", agent.get_volume_power, 0)

# 3. 기간별 프로그램 매매 상세 (7일간)
past_7days = (datetime.now() - timedelta(days=7)).strftime('%Y%m%d')
test_api_method("get_program_trade_period_detail", agent.get_program_trade_period_detail, past_7days, TEST_DATE)
# Out:
# ==================================================
# 🏦 Agent 회원사/거래 테스트
# ==================================================
#
# 🔍 테스트: get_member_transaction
# 📝 파라미터: args=('005930',), kwargs={}
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# 2025-06-19 00:11:56,029 - root - ERROR - 체결강도 순위 조회 실패: 'STOCK_FLUCTUATION'
# ✅ 성공: get_member_transaction (응답시간: 0.05초)
# 📊 응답 키: ['output', 'rt_cd', 'msg_cd', 'msg1']
# 📋 데이터 수: 20개
#
# 🔍 테스트: get_volume_power
# 📝 파라미터: args=(0,), kwargs={}
# ❌ 실패: get_volume_power - 결과 없음
#
# 🔍 테스트: get_program_trade_period_detail
# 📝 파라미터: args=('20250612', '20250619'), kwargs={}
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# ✅ 성공: get_program_trade_period_detail (응답시간: 0.06초)
# 📊 응답 키: ['output', 'rt_cd', 'msg_cd', 'msg1']
# {'output': [], 'rt_cd': '0', 'msg_cd': 'MCA00000', 'msg1': '정상처리 되었습니다.'}

# %%
# 💰 Agent 테스트 - 계좌 관련 정보
print("=" * 50)
print("💰 Agent 계좌 관련 테스트")
print("=" * 50)

print("⚠️ 참고: 실제 계좌 정보가 필요한 API들입니다.")

# 1. 계좌 잔고 조회
test_api_method("get_account_balance", agent.get_account_balance)

# 2. 주문 가능 금액 조회
test_api_method("get_possible_order_amount", agent.get_possible_order_amount)

# 3. 총 평가 금액 조회
test_api_method("get_total_evaluation", agent.get_total_evaluation)

# 4. 계좌별 주문 수량 조회
test_api_method("get_account_order_quantity", agent.get_account_order_quantity, TEST_STOCK)
# Out:
# ==================================================
# 💰 Agent 계좌 관련 테스트
# ==================================================
# ⚠️ 참고: 실제 계좌 정보가 필요한 API들입니다.
#
# 🔍 테스트: get_account_balance
# 📝 파라미터: args=(), kwargs={}
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# ✅ 성공: get_account_balance - 타입: <class 'pandas.core.frame.DataFrame'>
#
# 🔍 테스트: get_possible_order_amount
# 📝 파라미터: args=(), kwargs={}
# ❌ 예외 발생: get_possible_order_amount - 'AccountAPI' object has no attribute 'get_possible_order_amount'
#
# 🔍 테스트: get_total_evaluation
# 📝 파라미터: args=(), kwargs={}
# ❌ 예외 발생: get_total_evaluation - 'AccountAPI' object has no attribute 'get_total_evaluation'
#
# 🔍 테스트: get_account_order_quantity
# 📝 파라미터: args=('005930',), kwargs={}
# ❌ 예외 발생: get_account_order_quantity - 'AccountAPI' object has no attribute 'get_account_order_quantity'

# %%
# 🔧 Agent 테스트 - 전략 및 유틸리티
print("=" * 50)
print("🔧 Agent 전략/유틸리티 테스트")
print("=" * 50)

# 1. 매수 진입 조건 체크
test_api_method("check_entry_condition", agent.check_entry_condition, TEST_STOCK)

# 2. 매도 진출 조건 체크
test_api_method("check_exit_condition", agent.check_exit_condition, TEST_STOCK)

# 3. 전략 모니터링
test_api_method("monitor_strategy", agent.monitor_strategy, TEST_STOCK)

# 4. 조건검색식 종목 조회
test_api_method("get_condition_stocks", agent.get_condition_stocks)
# Out:
# 2025-06-19 00:11:56,174 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,174 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,174 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,174 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,174 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,175 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,175 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,175 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,175 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,176 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,176 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,176 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,176 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,176 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,177 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,177 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,178 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,178 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,178 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,178 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# ==================================================
# 🔧 Agent 전략/유틸리티 테스트
# ==================================================
#
# 🔍 테스트: check_entry_condition
# 📝 파라미터: args=('005930',), kwargs={}
# ⚠️ 부분 성공: check_entry_condition - rt_cd: None, msg:
#
# 🔍 테스트: check_exit_condition
# 📝 파라미터: args=('005930',), kwargs={}
# ⚠️ 부분 성공: check_exit_condition - rt_cd: None, msg:
#
# 🔍 테스트: monitor_strategy
# 📝 파라미터: args=('005930',), kwargs={}
# ⚠️ 부분 성공: monitor_strategy - rt_cd: None, msg:
#
# 🔍 테스트: get_condition_stocks
# 📝 파라미터: args=(), kwargs={}
# 2025-06-19 00:11:56,178 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,179 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,179 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,179 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,179 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,179 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,180 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,180 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,180 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,180 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,180 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,181 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,181 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,181 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,181 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,181 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,182 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,182 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,182 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,182 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,182 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,183 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,183 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,183 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,183 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,183 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,184 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,184 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,184 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,184 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,184 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,184 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,185 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,185 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,185 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,185 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,185 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,186 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,186 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,186 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,186 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,186 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,187 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,187 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,187 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,187 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,187 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,188 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,188 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,188 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,188 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,188 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,189 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,191 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,192 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,192 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,192 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,192 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,193 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,193 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,193 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,193 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,193 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,194 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,194 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,194 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,194 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,194 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,195 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,195 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,196 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,196 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,196 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,196 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,196 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,197 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,197 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,197 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,197 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,197 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,198 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,198 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,198 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,198 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,198 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,199 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,199 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,199 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,200 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,200 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,200 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,201 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,201 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,201 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,201 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,201 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,202 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,202 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,202 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,202 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,202 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,203 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,203 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,203 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,203 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,203 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,204 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,204 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,204 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,204 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,205 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,206 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,206 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,206 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,206 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,206 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,207 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,207 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,207 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,207 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,207 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,207 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,208 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,208 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,208 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,208 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,209 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,209 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,209 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,209 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,209 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,210 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,210 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,210 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,211 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,211 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,212 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,212 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,212 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,212 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,213 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,213 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,213 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,214 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,214 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,214 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,214 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,214 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,215 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,215 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,215 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,215 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,216 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,216 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,216 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,216 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,216 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,217 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,217 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,217 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,217 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,218 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,218 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,218 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,219 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,219 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,219 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,219 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,219 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,220 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,220 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,220 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,221 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,221 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,221 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,221 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,221 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,222 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,222 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,222 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,222 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,222 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,223 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,223 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,223 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,223 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,223 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,224 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,224 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,224 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,224 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,224 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,225 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,226 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,226 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,226 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,226 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,227 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,227 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,227 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,227 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,228 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,228 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,228 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,228 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,228 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,229 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,229 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,229 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,229 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,229 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,230 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,230 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,230 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,230 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,230 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,231 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,231 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,231 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,231 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,231 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,231 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,232 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,232 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,232 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,232 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,232 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,233 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,233 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,233 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,233 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,233 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,234 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,234 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,234 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,234 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,234 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,235 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,235 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,235 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,235 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,235 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,238 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,238 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,238 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,238 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,238 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,239 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,239 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,239 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,239 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,239 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,239 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,240 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,240 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,240 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,240 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,241 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,241 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,241 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,241 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,241 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,242 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,242 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,242 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,242 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,242 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,243 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,243 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,243 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,243 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,243 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,244 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,244 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,244 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,244 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,244 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,244 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,245 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,245 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,245 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,245 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,245 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,246 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,246 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,246 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,246 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,246 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,249 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,249 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,249 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,249 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,250 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,250 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,250 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,250 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,250 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,251 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,251 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,251 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,251 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,251 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,252 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,252 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,252 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,252 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,252 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,253 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,253 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,253 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,253 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,253 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,254 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,254 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,254 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,254 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,254 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,255 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,255 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,255 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,255 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,255 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,256 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,256 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,256 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,256 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,256 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,256 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,257 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,257 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,257 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,257 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,257 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,258 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,258 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,258 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,258 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,258 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,261 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,261 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,261 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,261 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,261 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,262 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,262 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,262 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,262 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,262 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,263 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,263 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,263 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,263 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,263 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,264 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,264 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,265 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,265 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,265 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,265 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,266 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,266 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,266 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,266 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,266 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,267 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,267 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,267 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,267 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,267 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,268 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,268 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,268 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,268 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,268 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,269 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,269 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,269 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,269 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,269 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,269 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,270 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,270 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,270 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,270 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,270 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,271 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,271 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,271 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,271 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,271 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,272 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,272 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,272 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,272 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,272 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,273 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,273 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,273 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,273 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,273 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,274 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,274 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,274 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,274 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,274 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,274 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,275 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,275 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,275 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,275 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,275 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,276 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,276 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,276 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,276 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,276 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,277 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,277 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,277 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,277 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,277 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,278 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,278 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,278 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,278 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,278 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,279 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,279 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,279 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,279 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,283 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,283 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,283 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,283 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,283 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,284 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,284 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,284 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,284 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,284 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,285 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,285 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,285 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,285 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,285 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,286 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,286 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,286 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,286 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,286 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,287 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,287 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,287 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,287 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,287 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,288 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,288 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,288 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,288 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,288 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,289 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,289 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,289 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,289 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,289 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,290 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,290 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,290 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,290 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,290 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,291 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,291 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,291 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,291 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,291 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,291 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,292 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,292 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,292 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,292 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,292 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,293 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,293 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,293 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,293 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,293 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,294 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,294 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,294 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,294 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,294 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,295 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,295 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,295 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,295 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,295 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,296 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,296 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,296 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,296 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,297 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,297 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,297 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,297 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,297 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,298 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,298 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,298 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,298 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,298 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,299 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,299 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,299 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,299 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,299 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,299 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,300 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,300 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,300 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,300 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,300 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,301 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,301 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,301 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,301 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,301 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,302 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,302 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,302 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,302 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,302 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,303 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# ...
# 2025-06-19 00:11:56,486 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,486 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,486 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,486 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,487 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,487 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,487 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,487 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,487 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,488 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,488 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,488 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,488 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,488 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,489 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,489 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,489 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,489 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,489 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,490 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,490 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,490 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,490 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,490 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,490 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,491 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,491 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,491 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,491 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,491 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,492 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,492 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,492 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,492 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,492 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,493 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,493 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,493 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,493 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,493 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,494 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,494 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,494 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,494 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,494 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,495 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,495 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,495 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,495 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,495 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,496 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,496 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,496 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,507 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,507 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,507 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,507 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,507 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,508 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,508 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,508 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,508 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,508 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,509 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,509 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,509 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,509 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,509 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,510 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,510 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,510 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,510 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,510 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,511 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,511 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,511 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,511 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,511 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,512 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,512 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,512 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,512 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,512 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,513 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,513 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,515 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,515 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,515 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,515 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,515 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,516 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,516 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,516 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,516 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,516 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,516 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,517 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,517 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,517 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,517 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,517 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,518 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,518 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,518 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,518 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,518 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,519 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,519 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,519 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,519 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,519 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,520 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,520 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,520 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,520 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,520 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,521 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,521 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,521 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,521 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,521 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,522 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,522 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,522 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,522 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,522 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,523 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,523 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,523 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,523 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,523 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,523 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,524 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,524 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,524 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,524 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,524 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,525 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,525 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,525 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,525 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,525 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,526 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,526 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,526 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,529 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,529 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,529 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,530 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,530 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,530 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,530 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,530 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,531 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,531 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,531 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,531 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,531 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,532 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,532 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,532 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,532 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,532 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,533 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,533 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,533 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,533 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,533 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,534 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,534 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,534 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,534 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,534 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,535 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,535 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,535 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,535 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,535 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,536 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,536 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,536 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,536 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,536 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,537 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# 2025-06-19 00:11:56,537 - root - ERROR - 조건검색식 종목 조회 실패: name 'logger' is not defined
# ⚠️ 부분 성공: get_condition_stocks - rt_cd: None, msg:
# {}

# %%
# 📊 Agent 테스트 - 시장 정보 및 기타
print("=" * 50)
print("📊 Agent 시장정보/기타 테스트")
print("=" * 50)

# 1. 상위 상승주 조회
test_api_method("get_top_gainers", agent.get_top_gainers)

# 2. 휴장일 확인
test_api_method("is_holiday", agent.is_holiday, TEST_DATE)

# 3. 거래원 분류 (유틸리티 메서드)
print("\n🔧 거래원 분류 테스트:")
print(f"   • 키움증권: {Agent.classify_broker('키움증권')}")
print(f"   • 골드만삭스: {Agent.classify_broker('골드만삭스')}")
print(f"   • 삼성증권: {Agent.classify_broker('삼성증권')}")

# 4. 분봉 데이터 조회 (캐싱 기능)
test_api_method("fetch_minute_data", agent.fetch_minute_data, TEST_STOCK, TEST_DATE)
# Out:
# 2025-06-19 00:11:56,545 - root - ERROR - 상승률 상위 종목 조회 실패: 'StockAPI' object has no attribute 'get_top_gainers'
# 2025-06-19 00:11:56,546 - root - DEBUG - 캐시에서 휴장일 정보 조회: 20250619 -> False
# 2025-06-19 00:11:56,547 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): openapi.koreainvestment.com:9443
# 2025-06-19 00:11:56,646 - urllib3.connectionpool - DEBUG - https://openapi.koreainvestment.com:9443 "GET /uapi/domestic-stock/v1/quotations/inquire-time-itemchartprice?FID_COND_MRKT_DIV_CODE=J&FID_COND_SCR_DIV_CODE=20171&FID_INPUT_ISCD=005930&FID_INPUT_HOUR_1=0900&FID_PW_DATA_INCU_YN=Y HTTP/1.1" 200 34
# 2025-06-19 00:11:56,646 - pykis.core.client - WARNING - [FHKST03010200] API 오류 응답 (시도 1/5):  (code: )
# ==================================================
# 📊 Agent 시장정보/기타 테스트
# ==================================================
#
# 🔍 테스트: get_top_gainers
# 📝 파라미터: args=(), kwargs={}
# ✅ 성공: get_top_gainers - 타입: <class 'list'>
#
# 🔍 테스트: is_holiday
# 📝 파라미터: args=('20250619',), kwargs={}
# ✅ 성공: is_holiday - 타입: <class 'bool'>
#
# 🔧 거래원 분류 테스트:
#    • 키움증권: 리테일/국내기관
#    • 골드만삭스: 외국계
#    • 삼성증권: 리테일/국내기관
#
# 🔍 테스트: fetch_minute_data
# 📝 파라미터: args=('005930', '20250619'), kwargs={}
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# 2025-06-19 00:11:56,748 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): openapi.koreainvestment.com:9443
# 2025-06-19 00:11:56,821 - urllib3.connectionpool - DEBUG - https://openapi.koreainvestment.com:9443 "GET /uapi/domestic-stock/v1/quotations/inquire-time-itemchartprice?FID_COND_MRKT_DIV_CODE=J&FID_COND_SCR_DIV_CODE=20171&FID_INPUT_ISCD=005930&FID_INPUT_HOUR_1=1000&FID_PW_DATA_INCU_YN=Y HTTP/1.1" 200 34
# 2025-06-19 00:11:56,822 - pykis.core.client - WARNING - [FHKST03010200] API 오류 응답 (시도 1/5):  (code: )
# 2025-06-19 00:11:56,923 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): openapi.koreainvestment.com:9443
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# 2025-06-19 00:11:57,011 - urllib3.connectionpool - DEBUG - https://openapi.koreainvestment.com:9443 "GET /uapi/domestic-stock/v1/quotations/inquire-time-itemchartprice?FID_COND_MRKT_DIV_CODE=J&FID_COND_SCR_DIV_CODE=20171&FID_INPUT_ISCD=005930&FID_INPUT_HOUR_1=1100&FID_PW_DATA_INCU_YN=Y HTTP/1.1" 200 34
# 2025-06-19 00:11:57,012 - pykis.core.client - WARNING - [FHKST03010200] API 오류 응답 (시도 1/5):  (code: )
# 2025-06-19 00:11:57,113 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): openapi.koreainvestment.com:9443
# 2025-06-19 00:11:57,219 - urllib3.connectionpool - DEBUG - https://openapi.koreainvestment.com:9443 "GET /uapi/domestic-stock/v1/quotations/inquire-time-itemchartprice?FID_COND_MRKT_DIV_CODE=J&FID_COND_SCR_DIV_CODE=20171&FID_INPUT_ISCD=005930&FID_INPUT_HOUR_1=1200&FID_PW_DATA_INCU_YN=Y HTTP/1.1" 200 34
# 2025-06-19 00:11:57,220 - pykis.core.client - WARNING - [FHKST03010200] API 오류 응답 (시도 1/5):  (code: )
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# 2025-06-19 00:11:57,320 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): openapi.koreainvestment.com:9443
# 2025-06-19 00:11:57,386 - urllib3.connectionpool - DEBUG - https://openapi.koreainvestment.com:9443 "GET /uapi/domestic-stock/v1/quotations/inquire-time-itemchartprice?FID_COND_MRKT_DIV_CODE=J&FID_COND_SCR_DIV_CODE=20171&FID_INPUT_ISCD=005930&FID_INPUT_HOUR_1=1300&FID_PW_DATA_INCU_YN=Y HTTP/1.1" 200 34
# 2025-06-19 00:11:57,386 - pykis.core.client - WARNING - [FHKST03010200] API 오류 응답 (시도 1/5):  (code: )
# 2025-06-19 00:11:57,487 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): openapi.koreainvestment.com:9443
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# 2025-06-19 00:11:57,591 - urllib3.connectionpool - DEBUG - https://openapi.koreainvestment.com:9443 "GET /uapi/domestic-stock/v1/quotations/inquire-time-itemchartprice?FID_COND_MRKT_DIV_CODE=J&FID_COND_SCR_DIV_CODE=20171&FID_INPUT_ISCD=005930&FID_INPUT_HOUR_1=1400&FID_PW_DATA_INCU_YN=Y HTTP/1.1" 200 34
# 2025-06-19 00:11:57,592 - pykis.core.client - WARNING - [FHKST03010200] API 오류 응답 (시도 1/5):  (code: )
# 2025-06-19 00:11:57,692 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): openapi.koreainvestment.com:9443
# 2025-06-19 00:11:57,765 - urllib3.connectionpool - DEBUG - https://openapi.koreainvestment.com:9443 "GET /uapi/domestic-stock/v1/quotations/inquire-time-itemchartprice?FID_COND_MRKT_DIV_CODE=J&FID_COND_SCR_DIV_CODE=20171&FID_INPUT_ISCD=005930&FID_INPUT_HOUR_1=1500&FID_PW_DATA_INCU_YN=Y HTTP/1.1" 200 34
# 2025-06-19 00:11:57,765 - pykis.core.client - WARNING - [FHKST03010200] API 오류 응답 (시도 1/5):  (code: )
# 2025-06-19 00:11:57,866 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): openapi.koreainvestment.com:9443
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# 2025-06-19 00:11:57,977 - urllib3.connectionpool - DEBUG - https://openapi.koreainvestment.com:9443 "GET /uapi/domestic-stock/v1/quotations/inquire-time-itemchartprice?FID_COND_MRKT_DIV_CODE=J&FID_COND_SCR_DIV_CODE=20171&FID_INPUT_ISCD=005930&FID_INPUT_HOUR_1=1600&FID_PW_DATA_INCU_YN=Y HTTP/1.1" 200 34
# 2025-06-19 00:11:57,978 - pykis.core.client - WARNING - [FHKST03010200] API 오류 응답 (시도 1/5):  (code: )
# ✅ 성공: fetch_minute_data - 타입: <class 'pandas.core.frame.DataFrame'>
# Empty DataFrame
# Columns: []
# Index: []

# %%
# 🔧 Agent 테스트 - 다양한 파라미터 검증
print("=" * 50)
print("🔧 Agent 다양한 파라미터 테스트")
print("=" * 50)

# 1. 다른 종목으로 테스트 (LG전자)
TEST_STOCK_2 = "066570"
print(f"\n🏢 종목 변경 테스트: {TEST_STOCK_2} (LG전자)")

test_api_method("get_stock_price_LG", agent.get_stock_price, TEST_STOCK_2)
test_api_method("get_daily_price_LG", agent.get_daily_price, TEST_STOCK_2)

# 2. 과거 날짜로 프로그램매매 테스트
past_date = (datetime.now() - timedelta(days=7)).strftime('%Y%m%d')
print(f"\n🕒 과거 날짜 테스트: {past_date}")
test_api_method("get_program_trade_daily_past", agent.get_program_trade_daily_summary, TEST_STOCK, past_date)

# 3. 다양한 메서드 연계 테스트
print(f"\n🔗 연계 메서드 테스트:")
test_api_method("get_pgm_trade_with_params", agent.get_pgm_trade, TEST_STOCK)
# Out:
# 2025-06-19 00:11:58,085 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): openapi.koreainvestment.com:9443
# 2025-06-19 00:11:58,169 - urllib3.connectionpool - DEBUG - https://openapi.koreainvestment.com:9443 "GET /uapi/domestic-stock/v1/quotations/inquire-price?FID_COND_MRKT_DIV_CODE=J&FID_INPUT_ISCD=066570 HTTP/1.1" 200 1965
# 2025-06-19 00:11:58,170 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): openapi.koreainvestment.com:9443
# 2025-06-19 00:11:58,236 - urllib3.connectionpool - DEBUG - https://openapi.koreainvestment.com:9443 "GET /uapi/domestic-stock/v1/quotations/inquire-daily-price?fid_cond_mrkt_div_code=J&fid_input_iscd=066570&fid_period_div_code=D&fid_org_adj_prc=1 HTTP/1.1" 200 9446
# 2025-06-19 00:11:58,237 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): openapi.koreainvestment.com:9443
# ==================================================
# 🔧 Agent 다양한 파라미터 테스트
# ==================================================
#
# 🏢 종목 변경 테스트: 066570 (LG전자)
#
# 🔍 테스트: get_stock_price_LG
# 📝 파라미터: args=('066570',), kwargs={}
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# ✅ 성공: get_stock_price_LG (응답시간: 0.08초)
# 📊 응답 키: ['output', 'rt_cd', 'msg_cd', 'msg1']
# 📋 데이터 키: ['iscd_stat_cls_code', 'marg_rate', 'rprs_mrkt_kor_name', 'bstp_kor_isnm', 'temp_stop_yn', 'oprc_rang_cont_yn', 'clpr_rang_cont_yn', 'crdt_able_yn', 'grmn_rate_cls_code', 'elw_pblc_yn', 'stck_prpr', 'prdy_vrss', 'prdy_vrss_sign', 'prdy_ctrt', 'acml_tr_pbmn', 'acml_vol', 'prdy_vrss_vol_rate', 'stck_oprc', 'stck_hgpr', 'stck_lwpr', 'stck_mxpr', 'stck_llam', 'stck_sdpr', 'wghn_avrg_stck_prc', 'hts_frgn_ehrt', 'frgn_ntby_qty', 'pgtr_ntby_qty', 'pvt_scnd_dmrs_prc', 'pvt_frst_dmrs_prc', 'pvt_pont_val', 'pvt_frst_dmsp_prc', 'pvt_scnd_dmsp_prc', 'dmrs_val', 'dmsp_val', 'cpfn', 'rstc_wdth_prc', 'stck_fcam', 'stck_sspr', 'aspr_unit', 'hts_deal_qty_unit_val', 'lstn_stcn', 'hts_avls', 'per', 'pbr', 'stac_month', 'vol_tnrt', 'eps', 'bps', 'd250_hgpr', 'd250_hgpr_date', 'd250_hgpr_vrss_prpr_rate', 'd250_lwpr', 'd250_lwpr_date', 'd250_lwpr_vrss_prpr_rate', 'stck_dryy_hgpr', 'dryy_hgpr_vrss_prpr_rate', 'dryy_hgpr_date', 'stck_dryy_lwpr', 'dryy_lwpr_vrss_prpr_rate', 'dryy_lwpr_date', 'w52_hgpr', 'w52_hgpr_vrss_prpr_ctrt', 'w52_hgpr_date', 'w52_lwpr', 'w52_lwpr_vrss_prpr_ctrt', 'w52_lwpr_date', 'whol_loan_rmnd_rate', 'ssts_yn', 'stck_shrn_iscd', 'fcam_cnnm', 'cpfn_cnnm', 'frgn_hldn_qty', 'vi_cls_code', 'ovtm_vi_cls_code', 'last_ssts_cntg_qty', 'invt_caful_yn', 'mrkt_warn_cls_code', 'short_over_yn', 'sltr_yn', 'mang_issu_cls_code']
#
# 🔍 테스트: get_daily_price_LG
# 📝 파라미터: args=('066570',), kwargs={}
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# ✅ 성공: get_daily_price_LG (응답시간: 0.07초)
# 📊 응답 키: ['output', 'rt_cd', 'msg_cd', 'msg1']
# 📋 데이터 수: 30개
#
# 🕒 과거 날짜 테스트: 20250612
#
# 🔍 테스트: get_program_trade_daily_past
# 📝 파라미터: args=('005930', '20250612'), kwargs={}
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# 2025-06-19 00:11:58,306 - urllib3.connectionpool - DEBUG - https://openapi.koreainvestment.com:9443 "GET /uapi/domestic-stock/v1/quotations/program-trade-by-stock-daily?FID_COND_MRKT_DIV_CODE=J&FID_INPUT_ISCD=005930&FID_INPUT_DATE_1=20250612 HTTP/1.1" 200 13470
# 2025-06-19 00:11:58,307 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): openapi.koreainvestment.com:9443
# 2025-06-19 00:11:58,356 - urllib3.connectionpool - DEBUG - https://openapi.koreainvestment.com:9443 "GET /uapi/domestic-stock/v1/quotations/program-trade-by-stock-daily?FID_COND_MRKT_DIV_CODE=J&FID_INPUT_ISCD=005930&FID_INPUT_DATE_1=20250619 HTTP/1.1" 200 13489
# ✅ 성공: get_program_trade_daily_past (응답시간: 0.07초)
# 📊 응답 키: ['output', 'rt_cd', 'msg_cd', 'msg1']
# 📋 데이터 수: 30개
#
# 🔗 연계 메서드 테스트:
#
# 🔍 테스트: get_pgm_trade_with_params
# 📝 파라미터: args=('005930',), kwargs={}
# [디버그] getTREnv() 반환 타입: <class 'pykis.core.auth.KISEnv'>, 값: KISEnv(my_app='PSssn1nSV1GF2ipQ5dp7dJSJR4ZFi7xKT2mi', my_sec='SjlliJHKtC+RdYpZPqlYBNXCoc1RFWikwlPbi3hsZI1cefm+mYU1mm/mbRuSCQ1dxlo8Pug0t99Z7tHuxlUKEYvJtA97/EO8VvXbgKTtf+BjrhFZq85XbyhP8T2Wau7ZQSCzTE7KG0c4gz3vG9U+u3JlplvJ8TF1LDR0kxVVH9PGoKFGong=', my_acct='68867843', my_prod='01', my_token='Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImQzNzFlZjYxLTNhODctNDcxMy1hZjA1LTA3YzMxM2NmMmYxNiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MDMzNDc3NCwiaWF0IjoxNzUwMjQ4Mzc0LCJqdGkiOiJQU3NzbjFuU1YxR0YyaXBRNWRwN2RKU0pSNFpGaTd4S1QybWkifQ.G7RbLhDR33dCmMxAsZLZIWuf2iSGVKDxGwJg5MvjokgKY-2-lsMyOczbTurDfZwutgMb5QQ0_TOOLvZZFexTVA', my_url='https://openapi.koreainvestment.com:9443')
# ❌ 실패: get_pgm_trade_with_params - 결과 없음

# %%
# 📊 테스트 결과 종합 분석 및 요약
print("=" * 70)
print("📊 전체 테스트 결과 종합 분석")
print("=" * 70)

# 성공률 계산
total_tests = test_results['total_tests']
success_count = len(test_results['success'])
failed_count = len(test_results['failed'])
partial_count = len(test_results['partial'])

success_rate = (success_count / total_tests * 100) if total_tests > 0 else 0

print(f"\n📈 테스트 통계:")
print(f"   • 전체 테스트: {total_tests}개")
print(f"   • 성공: {success_count}개 ({success_rate:.1f}%)")
print(f"   • 실패: {failed_count}개")
print(f"   • 부분 성공: {partial_count}개")

print(f"\n✅ 성공한 메서드 ({len(test_results['success'])}개):")
for method in test_results['success']:
    print(f"   • {method}")

if test_results['partial']:
    print(f"\n⚠️ 부분 성공한 메서드 ({len(test_results['partial'])}개):")
    for method in test_results['partial']:
        print(f"   • {method}")

if test_results['failed']:
    print(f"\n❌ 실패한 메서드 ({len(test_results['failed'])}개):")
    for method in test_results['failed']:
        print(f"   • {method}")

print(f"\n🎯 권장 사용 메서드:")
print("   다음 메서드들이 가장 안정적으로 작동합니다:")
for method in test_results['success'][:10]:  # 상위 10개만 표시
    print(f"   ✓ {method}")

print(f"\n💡 Agent 클래스 장점:")
print("   • 단일 인터페이스로 모든 API 기능 접근 가능")
print("   • SRP 원칙에 따라 모듈별로 책임 분리")
print("   • Facade 패턴으로 복잡성 숨김")
print("   • 일관된 메서드 명명 규칙")

print("=" * 70)
print("🎉 Agent 기반 전체 API 테스트 완료!")
print("=" * 70)
# Out:
# ======================================================================
# 📊 전체 테스트 결과 종합 분석
# ======================================================================
#
# 📈 테스트 통계:
#    • 전체 테스트: 26개
#    • 성공: 14개 (53.8%)
#    • 실패: 7개
#    • 부분 성공: 5개
#
# ✅ 성공한 메서드 (14개):
#    • get_stock_price
#    • get_daily_price
#    • get_member
#    • get_program_trade_hourly_trend
#    • get_program_trade_daily_summary
#    • get_member_transaction
#    • get_program_trade_period_detail
#    • get_account_balance
#    • get_top_gainers
#    • is_holiday
#    • fetch_minute_data
#    • get_stock_price_LG
#    • get_daily_price_LG
#    • get_program_trade_daily_past
#
# ⚠️ 부분 성공한 메서드 (5개):
#    • get_minute_price
#    • check_entry_condition
#    • check_exit_condition
#    • monitor_strategy
#    • get_condition_stocks
#
# ❌ 실패한 메서드 (7개):
#    • get_program_trade_summary
#    • get_pgm_trade
#    • get_volume_power
#    • get_possible_order_amount
#    • get_total_evaluation
#    • get_account_order_quantity
#    • get_pgm_trade_with_params
#
# 🎯 권장 사용 메서드:
#    다음 메서드들이 가장 안정적으로 작동합니다:
#    ✓ get_stock_price
#    ✓ get_daily_price
#    ✓ get_member
#    ✓ get_program_trade_hourly_trend
#    ✓ get_program_trade_daily_summary
#    ✓ get_member_transaction
#    ✓ get_program_trade_period_detail
#    ✓ get_account_balance
#    ✓ get_top_gainers
#    ✓ is_holiday
#
# 💡 Agent 클래스 장점:
#    • 단일 인터페이스로 모든 API 기능 접근 가능
#    • SRP 원칙에 따라 모듈별로 책임 분리
#    • Facade 패턴으로 복잡성 숨김
#    • 일관된 메서드 명명 규칙
# ======================================================================
# 🎉 Agent 기반 전체 API 테스트 완료!
# ======================================================================
